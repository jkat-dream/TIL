# %% [markdown]
# <a href="https://colab.research.google.com/github/jkat-dream/TIL/blob/main/feat%3A%20delect%20some%20data%20mini_project_personal_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/mini project#1/파이널프로젝트_RAW_210329_210926.xlsx")

# %%
df.head(3)
# Out:
#        id  customer_id  course_id     type      state  \
# 0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2  970657      72297.0   204246.0  PAYMENT  COMPLETED
#
#                   course_title category_title  format        completed_at  \
# 0    올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원 2021-03-28 15:00:11
# 1  초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원 2021-03-28 15:16:53
# 2         시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인 2021-03-28 15:21:43
#
#    transaction_amount           coupon_title  coupon_discount_amount  \
# 0               90500                    NaN                     NaN
# 1               96000                    NaN                     NaN
# 2              171810  [10% 할인] 시크릿코드 실무 완성편                 19090.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
#
#   marketing_start_at
# 0                NaT
# 1         2020-12-02
# 2         2021-03-04

# %%
dellow = df.loc[df['id']==47361].index

# %%
df.drop(dellow, axis='index', inplace=True)

# %%
a = df.loc[df['transaction_amount']>10000000]
a
# Out:
#              id  customer_id  course_id     type      state  \
# 5299     985269     483435.0   204117.0  PAYMENT  COMPLETED
# 13053   1009567     496339.0   204510.0  PAYMENT  COMPLETED
# 13522   1011354     497618.0   204206.0  PAYMENT  COMPLETED
# 22694   1039468     512983.0   204638.0  PAYMENT  COMPLETED
# 23916   1042996     514474.0   204599.0  PAYMENT  COMPLETED
# 24138   1043335     514626.0   204616.0  PAYMENT  COMPLETED
# 30906   1062566     524163.0   204193.0  PAYMENT  COMPLETED
# 30990   1062847     524313.0   204550.0  PAYMENT  COMPLETED
# 36870   1080149     532992.0   205160.0  PAYMENT  COMPLETED
# 37946   1084684     535365.0   203999.0  PAYMENT  COMPLETED
# 42698   1115067     548656.0   204465.0  PAYMENT  COMPLETED
# 45247   1111250     547305.0   204256.0  PAYMENT  COMPLETED
# 46635   1114604     548381.0   203947.0  PAYMENT  COMPLETED
# 47361   1117129     549990.0        NaN  PAYMENT  COMPLETED
# 56395   1148921     564603.0   205367.0  PAYMENT  COMPLETED
# 58102   1154775     567160.0   204305.0  PAYMENT  COMPLETED
# 58271   1155233     567457.0   205223.0  PAYMENT  COMPLETED
# 72825   1213825     592788.0   205268.0    ORDER  CANCELLED
# 72832   1213930     592788.0   205268.0    ORDER  CANCELLED
# 72835   1213933     592788.0   205268.0    ORDER  CANCELLED
# 73268   1216653     551754.0   205886.0  PAYMENT  COMPLETED
# 73660   1217799     594969.0   204212.0  PAYMENT  COMPLETED
# 75463   1229628     600889.0   205311.0  PAYMENT  COMPLETED
# 76623   1229339     600763.0   204257.0  PAYMENT  COMPLETED
# 76654   1229341     600764.0   205676.0  PAYMENT  COMPLETED
# 76718   1229637     567457.0   205224.0  PAYMENT  COMPLETED
# 80285   1245177     610715.0   204523.0  PAYMENT  COMPLETED
# 80799   1247445     612391.0   205767.0  PAYMENT  COMPLETED
# 81591   1251558     116416.0   203992.0  PAYMENT  CANCELLED
# 81788   1252478     116416.0   203992.0  PAYMENT  COMPLETED
# 85783   1273684     589392.0   204188.0  PAYMENT  COMPLETED
# 87316   1280376     630176.0   206606.0  PAYMENT  COMPLETED
# 88200   1284700     572231.0   205574.0  PAYMENT  COMPLETED
# 91068   1296540     638045.0   205146.0  PAYMENT  COMPLETED
# 95606   1318092     567161.0   206854.0  PAYMENT  COMPLETED
# 100860  1340012     589292.0   207151.0  PAYMENT  COMPLETED
# 101976  1344408     661249.0   204280.0  PAYMENT  COMPLETED
# 102643  1347315     594969.0   204213.0  PAYMENT  COMPLETED
# 102991  1349252     534776.0   206465.0  PAYMENT  COMPLETED
# 103367  1352203     600764.0   206339.0  PAYMENT  COMPLETED
#
#                                              course_title category_title  \
# 5299                       (B2B) 신용보증기금 온라인 구독 싱글 플랜 (1차)             교육
# 13053                            (B2B) 고려해운 온라인 구독 (4월입과)             교육
# 13522                      (B2B) 제일기획 온라인 구독 싱글 플랜 (2021)             교육
# 22694                 (B2B) 서울형 청년인턴 디지털 마케팅 및 영업 과정 (국내)            마케팅
# 23916                           (B2B) 우송대학교 온라인 구독 패키지 플랜             교육
# 24138                    (B2B) KB데이타시스템 온라인 구독 싱글 플랜 (4월)             교육
# 30906            (B2B) LG전자 2021 Data Scientist 중급 과정 1차수        데이터사이언스
# 30990                       (B2B) kt ds 온라인 구독 싱글 플랜 (4월)             교육
# 36870                           (B2B) 오토닉스 온라인 구독 싱글/올 플랜             교육
# 37946                                  (B2B) 이마트 데이터 아카데미        데이터사이언스
# 42698                             (B2B) 한국리서치 온라인 구독 올 플랜             교육
# 45247                         (B2B) 동원그룹 데이터 기반 사고력 향상 과정        데이터사이언스
# 46635                        (B2B) 교보생명 교보 데이터 분석 전문과정 2기        데이터사이언스
# 47361                                                 NaN            NaN
# 56395                              (B2B) 경남대학교_코딩 테스트 대비반          프로그래밍
# 58102                   (B2B) 현대모비스 2021 데이터 분석 준전문가 양성과정        데이터사이언스
# 58271            (B2B) 아모레퍼시픽 R을 활용한 데이터 분석 이해 1차수 (2021)        데이터사이언스
# 72825                       (B2B) KB국민카드 2021 디지털아카데미 레벨2        데이터사이언스
# 72832                       (B2B) KB국민카드 2021 디지털아카데미 레벨2        데이터사이언스
# 72835                       (B2B) KB국민카드 2021 디지털아카데미 레벨2        데이터사이언스
# 73268                            (B2B) KT 온라인 구독 올 플랜(추가)             교육
# 73660   (B2B) 한라인재개발원 2021 Work Smart 프로그램 - 데이터 자동화 및...        데이터사이언스
# 75463               (B2B) 현대오토에버 온라인 싱글 플랜 - 직장인파이썬분석 포팅건        데이터사이언스
# 76623   (B2B) 두산경영연구원 2021 현업 프로젝트를 위한 데이터 분석 및 해석 과정 2차수        데이터사이언스
# 76654                            (B2B) 이마트 데이터 아카데미 (3차수)        데이터사이언스
# 76718            (B2B) 아모레퍼시픽 R을 활용한 데이터 분석 이해 2차수 (2021)        데이터사이언스
# 80285                           (B2B) (주)렉스코드 온라인 구독 올 플랜             교육
# 80799                            (B2B) KB증권 블록체인 개발 입문 과정          프로그래밍
# 81591                   (B2B) 하나금융티아이 DT University(2021)         크리에이티브
# 81788                   (B2B) 하나금융티아이 DT University(2021)         크리에이티브
# 85783                   (B2B) LG전자 2021 빅데이터 직무전환자 과정 2차수        데이터사이언스
# 87316         (B2B) 한국투자증권 신입사원 과정: 파이썬을 활용한 데이터 분석 실무 과정        데이터사이언스
# 88200                          (B2B) 임팩트캠퍼스 디지털 마케팅 프로젝트십            마케팅
# 91068                      (B2B) 신용보증기금 온라인 구독 싱글 플랜 (2차)             교육
# 95606                           (B2B) 미래에셋증권 DT교육 파이썬 Lv2        데이터사이언스
# 100860                      (B2B) kt ds 온라인 구독 싱글 플랜 (8월)             교육
# 101976                        (B2B) 농심 DIA GreenSeed 심화과정        데이터사이언스
# 102643      (B2B) 한라인재개발원 2021 Work Smart 프로그램 - 데이터 사이언스        데이터사이언스
# 102991                 (B2B) 롯데인재개발원 온라인 턴키 제휴 (2021년 8월)             교육
# 103367                           (B2B) 이마트 데이터 아카데미 (7차수)        데이터사이언스
#
#          format        completed_at  transaction_amount coupon_title  \
# 5299    B2B 온라인 2021-04-01 14:16:14            19953975          NaN
# 13053   B2B 온라인 2021-04-14 11:15:44            13836298          NaN
# 13522   B2B 온라인 2021-04-15 11:05:34            13303988          NaN
# 22694       B2B 2021-04-29 15:51:40           113400000          NaN
# 23916   B2B 온라인 2021-04-30 14:29:03            15054000          NaN
# 24138   B2B 온라인 2021-04-30 16:35:01            13693925          NaN
# 30906       B2B 2021-05-10 13:34:08            17220000          NaN
# 30990   B2B 온라인 2021-05-10 15:08:18            11318600          NaN
# 36870   B2B 온라인 2021-05-18 12:23:27            14491480          NaN
# 37946       B2B 2021-05-20 14:35:26            27040000          NaN
# 42698   B2B 온라인 2021-05-28 10:21:15            14400000          NaN
# 45247       B2B 2021-05-31 16:52:41            16200000          NaN
# 46635       B2B 2021-06-01 04:00:15            81040000          NaN
# 47361       NaN 2021-06-02 16:48:37            10500000          NaN
# 56395       B2B 2021-06-18 10:55:57            19503000          NaN
# 58102       B2B 2021-06-21 09:34:16            50665980          NaN
# 58271       B2B 2021-06-21 14:08:51            13500000          NaN
# 72825       B2B 2021-07-13 14:01:18            33797000          NaN
# 72832       B2B 2021-07-13 14:10:56            33797000          NaN
# 72835       B2B 2021-07-13 14:11:53            33797000          NaN
# 73268   B2B 온라인 2021-07-14 12:08:56            15000000          NaN
# 73660       B2B 2021-07-15 09:42:48            24800000          NaN
# 75463   B2B 온라인 2021-07-19 09:34:00            32314524          NaN
# 76623       B2B 2021-07-20 14:15:03            15600000          NaN
# 76654       B2B 2021-07-20 14:35:09            15298000          NaN
# 76718       B2B 2021-07-20 15:46:44            13500000          NaN
# 80285   B2B 온라인 2021-07-27 14:34:02            14449500          NaN
# 80799       B2B 2021-07-28 16:05:01            15900000          NaN
# 81591       B2B 2021-07-30 10:38:32            90940000          NaN
# 81788       B2B 2021-07-30 15:10:39            44600000          NaN
# 85783       B2B 2021-08-09 14:17:50            58100000          NaN
# 87316       B2B 2021-08-12 09:52:19            12000000          NaN
# 88200       B2G 2021-08-13 17:10:07            20000000          NaN
# 91068   B2B 온라인 2021-08-19 16:22:55            10119420          NaN
# 95606       B2B 2021-08-31 12:12:04            10090000          NaN
# 100860  B2B 온라인 2021-09-10 16:26:55            18672375          NaN
# 101976      B2B 2021-09-13 12:32:26            14400000          NaN
# 102643      B2B 2021-09-15 10:29:04            47500000          NaN
# 102991      B2B 2021-09-16 10:17:59            11305000          NaN
# 103367      B2B 2021-09-17 14:35:25            14792800          NaN
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg    method  \
# 5299                       NaN         NaN              NaN     NaN  TRANSFER
# 13053                      NaN         NaN              NaN     NaN  TRANSFER
# 13522                      NaN         NaN              NaN     NaN  TRANSFER
# 22694                      NaN         NaN              NaN     NaN  TRANSFER
# 23916                      NaN         NaN              NaN     NaN  TRANSFER
# 24138                      NaN         NaN              NaN     NaN  TRANSFER
# 30906                      NaN         NaN              NaN     NaN  TRANSFER
# 30990                      NaN         NaN              NaN     NaN  TRANSFER
# 36870                      NaN         NaN              NaN     NaN  TRANSFER
# 37946                      NaN         NaN              NaN     NaN  TRANSFER
# 42698                      NaN         NaN              NaN     NaN  TRANSFER
# 45247                      NaN         NaN              NaN     NaN  TRANSFER
# 46635                      NaN         NaN              NaN     NaN  TRANSFER
# 47361                      NaN         NaN              NaN     NaN  TRANSFER
# 56395                      NaN         NaN              NaN     NaN  TRANSFER
# 58102                      NaN         NaN              NaN     NaN  TRANSFER
# 58271                      NaN         NaN              NaN     NaN  TRANSFER
# 72825                      NaN  33797000.0       33797000.0  INICIS      CARD
# 72832                      NaN  33797000.0       33797000.0  INICIS      CARD
# 72835                      NaN  33797000.0       33797000.0   NAVER       NaN
# 73268                      NaN         NaN              NaN     NaN  TRANSFER
# 73660                      NaN         NaN              NaN     NaN  TRANSFER
# 75463                      NaN         NaN              NaN     NaN  TRANSFER
# 76623                      NaN         NaN              NaN     NaN  TRANSFER
# 76654                      NaN         NaN              NaN     NaN  TRANSFER
# 76718                      NaN         NaN              NaN     NaN  TRANSFER
# 80285                      NaN         NaN              NaN     NaN  TRANSFER
# 80799                      NaN  15900000.0       15900000.0     NaN  TRANSFER
# 81591                      NaN  90940000.0       90940000.0  INICIS      CARD
# 81788                      NaN  44600000.0       44600000.0  INICIS      CARD
# 85783                      NaN         NaN              NaN     NaN  TRANSFER
# 87316                      NaN         NaN              NaN     NaN  TRANSFER
# 88200                      NaN         NaN              NaN     NaN  TRANSFER
# 91068                      NaN         NaN              NaN     NaN  TRANSFER
# 95606                      NaN         NaN              NaN     NaN  TRANSFER
# 100860                     NaN         NaN              NaN     NaN  TRANSFER
# 101976                     NaN         NaN              NaN     NaN  TRANSFER
# 102643                     NaN         NaN              NaN     NaN  TRANSFER
# 102991                     NaN         NaN              NaN     NaN  TRANSFER
# 103367                     NaN         NaN              NaN     NaN  TRANSFER
#
#        subcategory_title marketing_start_at
# 5299                 NaN                NaT
# 13053                NaN                NaT
# 13522                NaN                NaT
# 22694                NaN                NaT
# 23916                NaN                NaT
# 24138                NaN                NaT
# 30906                NaN                NaT
# 30990                NaN                NaT
# 36870                NaN                NaT
# 37946                NaN                NaT
# 42698                NaN                NaT
# 45247                NaN                NaT
# 46635                NaN                NaT
# 47361                NaN                NaT
# 56395                NaN                NaT
# 58102                NaN                NaT
# 58271                NaN                NaT
# 72825                NaN                NaT
# 72832                NaN                NaT
# 72835                NaN                NaT
# 73268                NaN                NaT
# 73660                NaN                NaT
# 75463                NaN                NaT
# 76623                NaN                NaT
# 76654                NaN                NaT
# 76718                NaN                NaT
# 80285                NaN                NaT
# 80799                NaN                NaT
# 81591                NaN                NaT
# 81788                NaN                NaT
# 85783                NaN                NaT
# 87316                NaN                NaT
# 88200                NaN                NaT
# 91068                NaN                NaT
# 95606                NaN                NaT
# 100860               NaN                NaT
# 101976               NaN                NaT
# 102643               NaN                NaT
# 102991               NaN                NaT
# 103367               NaN                NaT

# %%
df['completed_at_ym'] = pd.to_datetime(df['completed_at'])
set_of_year_month = list(set([(x.year, x.month) for x in df['completed_at']]))
for ym in sorted(set_of_year_month, key=lambda x: (x[0], x[1])):
  print(f'{ym[0]}년 {ym[1]}월')
# Out:
# 2021년 3월
# 2021년 4월
# 2021년 5월
# 2021년 6월
# 2021년 7월
# 2021년 8월
# 2021년 9월

# %% [markdown]
# 마케팅 시작일과 구매일자를 비교해서 마케팅이 효과를 내기시작하는 날을 구한다.
#
# 월별판매액
# 일별판매액
# 품목별 판매건수
# RFM분석-최근구매, 자주구매, 지출을 많이 하는
# 재구매 비율
# 어떤 format이 가장 많이 팔렸는지
# 어떤 카테고리가 가장 많이 팔렸는지

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 105419 entries, 0 to 105418
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      105419 non-null  int64
#  1   customer_id             105416 non-null  float64
#  2   course_id               100212 non-null  float64
#  3   type                    105419 non-null  object
#  4   state                   105419 non-null  object
#  5   course_title            105403 non-null  object
#  6   category_title          105395 non-null  object
#  7   format                  105403 non-null  object
#  8   completed_at            105419 non-null  datetime64[ns]
#  9   transaction_amount      105419 non-null  int64
#  10  coupon_title            31817 non-null   object
#  11  coupon_discount_amount  31817 non-null   float64
#  12  sale_price              104291 non-null  float64
#  13  tax_free_amount         104291 non-null  float64
#  14  pg                      90344 non-null   object
#  15  method                  92323 non-null   object
#  16  subcategory_title       85590 non-null   object
#  17  marketing_start_at      87440 non-null   datetime64[ns]
#  18  completed_at_ym         105419 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(5), int64(2), object(9)
# memory usage: 16.1+ MB

# %%
#코호트 분석
co_df = df[['customer_id', 'completed_at']]
co_df.head
# Out:
# <bound method NDFrame.head of         customer_id        completed_at
# 0          504760.0 2021-03-28 15:00:11
# 1          432862.0 2021-03-28 15:16:53
# 2           72297.0 2021-03-28 15:21:43
# 3           72297.0 2021-03-28 15:21:43
# 4          478028.0 2021-03-28 15:21:54
# ...             ...                 ...
# 105414     640697.0 2021-09-25 14:10:42
# 105415     670896.0 2021-09-25 14:16:33
# 105416     640697.0 2021-09-25 14:17:41
# 105417     670896.0 2021-09-25 14:19:56
# 105418     610626.0 2021-09-25 14:25:47
#
# [105419 rows x 2 columns]>

# %%
co_df['completed_at'].dtype
# Out:
# dtype('<M8[ns]')

# %%
co_df['order-period'] = co_df['completed_at'].dt.strftime('%Y-%m')
co_df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    customer_id        completed_at order-period
# 0     504760.0 2021-03-28 15:00:11      2021-03
# 1     432862.0 2021-03-28 15:16:53      2021-03
# 2      72297.0 2021-03-28 15:21:43      2021-03
# 3      72297.0 2021-03-28 15:21:43      2021-03
# 4     478028.0 2021-03-28 15:21:54      2021-03

# %%
#동일한 경험을 첫 번째 주문으로 가정하고 사용자 유지율을 분석함
co_df.set_index('customer_id', inplace=True)
co_df.head()
# Out:
#                    completed_at order-period
# customer_id
# 504760.0    2021-03-28 15:00:11      2021-03
# 432862.0    2021-03-28 15:16:53      2021-03
# 72297.0     2021-03-28 15:21:43      2021-03
# 72297.0     2021-03-28 15:21:43      2021-03
# 478028.0    2021-03-28 15:21:54      2021-03

# %%
FirstOrder=df.groupby(co_df.index)['completed_at'].min()
FirstOrder.head()
# Out:
# customer_id
# 16.0   2021-04-28 15:55:26
# 46.0   2021-05-02 20:28:11
# 47.0   2021-04-29 18:32:15
# 79.0   2021-03-30 13:59:52
# 96.0   2021-09-21 17:51:18
# Name: completed_at, dtype: datetime64[ns]

# %%
FirstOrder = FirstOrder.dt.strftime('%Y-%m')

# %%
co_df['FirstOrder'] = FirstOrder
co_df.reset_index(inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
co_df
# Out:
#         customer_id        completed_at order-period FirstOrder
# 0          504760.0 2021-03-28 15:00:11      2021-03    2021-03
# 1          432862.0 2021-03-28 15:16:53      2021-03    2021-03
# 2           72297.0 2021-03-28 15:21:43      2021-03    2021-03
# 3           72297.0 2021-03-28 15:21:43      2021-03    2021-03
# 4          478028.0 2021-03-28 15:21:54      2021-03    2021-03
# ...             ...                 ...          ...        ...
# 105414     640697.0 2021-09-25 14:10:42      2021-09    2021-09
# 105415     670896.0 2021-09-25 14:16:33      2021-09    2021-09
# 105416     640697.0 2021-09-25 14:17:41      2021-09    2021-09
# 105417     670896.0 2021-09-25 14:19:56      2021-09    2021-09
# 105418     610626.0 2021-09-25 14:25:47      2021-09    2021-09
#
# [105419 rows x 4 columns]

# %%
grouped = co_df.groupby (['FirstOrder', 'order-period'])

# %%
cohorts=grouped['customer_id'].nunique()
cohorts.head()
# Out:
# FirstOrder  order-period
# 2021-03     2021-03         3123
#             2021-04          446
#             2021-05          268
#             2021-06          216
#             2021-07          190
# Name: customer_id, dtype: int64

# %%
cohorts=cohorts.reset_index()
cohorts.head()
# Out:
#   FirstOrder order-period  customer_id
# 0    2021-03      2021-03         3123
# 1    2021-03      2021-04          446
# 2    2021-03      2021-05          268
# 3    2021-03      2021-06          216
# 4    2021-03      2021-07          190

# %% [markdown]
# customer id는 처음 가져왔을때 고객별 데이터였지만 지금은 순방문자수를 집계한 데이터로 구성됨.

# %%
cohorts.rename({'customer_id':'totalusers'}, axis=1, inplace=True)
cohorts.head()
# Out:
#   FirstOrder order-period  totalusers
# 0    2021-03      2021-03        3123
# 1    2021-03      2021-04         446
# 2    2021-03      2021-05         268
# 3    2021-03      2021-06         216
# 4    2021-03      2021-07         190

# %%
each_period=cohorts['FirstOrder'].value_counts().sort_index()
each_period
# Out:
# 2021-03    7
# 2021-04    6
# 2021-05    5
# 2021-06    4
# 2021-07    3
# 2021-08    2
# 2021-09    1
# Name: FirstOrder, dtype: int64

# %%
cohortperiod=[]
for x in each_period:
  for y in range(x):
    cohortperiod.append(y)

# %%
cohorts['cohortperiod'] = cohortperiod
cohorts.head()
# Out:
#   FirstOrder order-period  totalusers  cohortperiod
# 0    2021-03      2021-03        3123             0
# 1    2021-03      2021-04         446             1
# 2    2021-03      2021-05         268             2
# 3    2021-03      2021-06         216             3
# 4    2021-03      2021-07         190             4

# %%
cohorts.set_index(['FirstOrder', 'cohortperiod'], inplace=True)
cohorts.head()
# Out:
#                         order-period  totalusers
# FirstOrder cohortperiod
# 2021-03    0                 2021-03        3123
#            1                 2021-04         446
#            2                 2021-05         268
#            3                 2021-06         216
#            4                 2021-07         190

# %%
cohorts=cohorts['totalusers'].unstack(1)
cohorts
# Out:
# cohortperiod        0       1      2      3      4      5      6
# FirstOrder
# 2021-03        3123.0   446.0  268.0  216.0  190.0  199.0  121.0
# 2021-04       10471.0  1118.0  773.0  601.0  480.0  375.0    NaN
# 2021-05       10987.0  1572.0  504.0  410.0  278.0    NaN    NaN
# 2021-06        9251.0   727.0  370.0  230.0    NaN    NaN    NaN
# 2021-07        8260.0   970.0  278.0    NaN    NaN    NaN    NaN
# 2021-08        7495.0   847.0    NaN    NaN    NaN    NaN    NaN
# 2021-09        4166.0     NaN    NaN    NaN    NaN    NaN    NaN

# %% [markdown]
# 처음의 순방문자 수에 비해 각 기간의 순방문자수가 얼마나 변화하였는지에 대한 것

# %%
user_retention = cohorts.divide(cohorts[0], axis=0)
user_retention
# Out:
# cohortperiod    0         1         2         3         4         5         6
# FirstOrder
# 2021-03       1.0  0.142811  0.085815  0.069164  0.060839  0.063721  0.038745
# 2021-04       1.0  0.106771  0.073823  0.057397  0.045841  0.035813       NaN
# 2021-05       1.0  0.143078  0.045872  0.037317  0.025303       NaN       NaN
# 2021-06       1.0  0.078586  0.039996  0.024862       NaN       NaN       NaN
# 2021-07       1.0  0.117433  0.033656       NaN       NaN       NaN       NaN
# 2021-08       1.0  0.113009       NaN       NaN       NaN       NaN       NaN
# 2021-09       1.0       NaN       NaN       NaN       NaN       NaN       NaN

# %%
plt.figure(figsize=(12,8))
plt.title('Cohort Analysis', fontsize=19)
sns.heatmap(user_retention, annot=True, fmt='.0%')
plt.show()

# %%
print(df['format'].value_counts())
# Out:
# 올인원        87402
# RED         6253
# 온라인 완주반     3817
# 하루10분컷      2978
# B2B 온라인     1086
# 스쿨 온라인      1057
# 스쿨          1036
# B2B          808
# B2G          592
# 이벤트          193
# 아카이브          72
# MBA           56
# 캠프            48
# 관리             2
# 콜로소            2
# 온라인            1
# Name: format, dtype: int64

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fv
#!rm ~/.cache/matplotlib -rf

# %%
from matplotlib import font_manager, rc
plt.rc('font', family='NanumBarunGothic')

# %%
df['format'].value_counts().plot(kind='pie', figsize=(15,10), autopct='%1.1f%%', startangle=10)
plt.title('Purchase item ratio', size=12)
plt.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#RFM분석 전 기업 고객의 데이터 삭제하기
B2B = df[df['format'].str.contains("B2B", na=False, case=False)].index
df.drop(B2B,  axis='index', inplace=True)

# %%
#환불된 경우 제외
minus = df.loc[df['transaction_amount'] < 0].index
df.drop(minus, axis='index', inplace=True)

# %%
#RFM분석
df_user = pd.DataFrame(df['customer_id'])
df_user.columns=['customer_id']
df_max_purchase = df.groupby('customer_id')['completed_at'].max().reset_index()
df_max_purchase.rename(columns = {'completed_at': 'max_purchase'}, inplace = True)

# %%
df_max_purchase['recency'] = (df_max_purchase['max_purchase'].max() - df_max_purchase['max_purchase']).dt.days
df_user = pd.merge(df_user, df_max_purchase[['customer_id', 'recency']], on='customer_id')

# %%
df_user.recency.describe()
# Out:
# count    99808.000000
# mean        89.117606
# std         51.598817
# min          0.000000
# 25%         44.000000
# 50%         89.000000
# 75%        133.000000
# max        180.000000
# Name: recency, dtype: float64

# %%
sns.set(palette='muted', color_codes=True, style='white')
fig, ax = plt.subplots(figsize=(12,8))
sns.despine(left=True)
sns.distplot(df_user['recency'], bins=30)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# 데이터상 전체 고객의 가장 최근 구매 날짜를 기준으로 잡고 이 날짜와 고객 각 한명당 최근에 구매한 날짜 차이의 평균은 88일 전이라는 것을 확인
# 그 시간 차이의 흐름을 확인한 그래프임

# %%
#frequency
df_frequency = df.groupby ('customer_id').completed_at.count().reset_index()
df_frequency.rename(columns={'completed_at':'frequency'}, inplace = True)

df_user = pd.merge(df_user, df_frequency, on='customer_id')
df_user.frequency.describe()
# Out:
# count    99808.000000
# mean         3.670888
# std          5.326828
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max         78.000000
# Name: frequency, dtype: float64

# %%
sns.set(palette='muted', color_codes=True, style='whitegrid')
fig, ax = plt.subplots(figsize=(12, 6))
sns.despine(left=True)
sns.distplot(df_user['frequency'], hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#monetary
df_revenue = df.groupby('customer_id').transaction_amount.sum().reset_index()
df_revenue.rename(columns={'transaction_amount':'revenue'}, inplace = True)
df_user = pd.merge(df_user, df_revenue, on = 'customer_id')
df_user.revenue.describe()
# Out:
# count    9.980800e+04
# mean     4.824173e+05
# std      7.288320e+05
# min      0.000000e+00
# 25%      1.490000e+05
# 50%      2.780000e+05
# 75%      5.320000e+05
# max      2.000000e+07
# Name: revenue, dtype: float64

# %%
sns.set(palette='muted', color_codes=True, style='white')
fig, ax = plt.subplots(figsize=(12, 6))
sns.despine(left=True)
sns.distplot(df_user['revenue'], hist=False)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
df_user.head()
# Out:
#    customer_id  recency  frequency  revenue
# 0     504760.0      180          1    90500
# 1     432862.0      180          1    96000
# 2      72297.0       42          9  1008120
# 3      72297.0       42          9  1008120
# 4      72297.0       42          9  1008120

# %%
def rec(x):
  if x <= 44:
    return 1
  elif x <= 89:
    return 2
  elif x <=133:
    return 3
  else:
    return 4

df_user['recency_score'] = df_user['recency'].map(rec)

# %%
def fre(x):
  if x <= 1:
    return 1
  elif x <= 2:
    return 2
  elif x <=4:
    return 3
  else:
    return 4

df_user['frequency_score'] = df_user['frequency'].map(fre)

# %%
def rev(x):
  if x <= 1.490000e+05:
    return 1
  elif x <= 2.780000e+05:
    return 2
  elif x<= 5.320000e+05:
    return 3
  else:
    return 4

df_user['revenue_score'] = df_user['revenue'].map(rev)

# %%
df_user.head()
# Out:
#    customer_id  recency  frequency  revenue  recency_score  frequency_score  \
# 0     504760.0      180          1    90500              4                1
# 1     432862.0      180          1    96000              4                1
# 2      72297.0       42          9  1008120              1                4
# 3      72297.0       42          9  1008120              1                4
# 4      72297.0       42          9  1008120              1                4
#
#    revenue_score
# 0              1
# 1              1
# 2              4
# 3              4
# 4              4

# %% [markdown]
# 초우량 고객 rfm이 모두 높음
# 저수익성 고객 rf는 높지만 m이 낮음
# 신규고객rm은 높지만 f가 낮은 고객
# 이탈고객 fm은 높지만r이 낮은 고객

# %% [markdown]
# r,f,m >= 3 ; 초우량 고객
# r,f>=3, m < 3; 저수익성 고객
# r,m >=3, f < 3; 신규고객
# f,m>=3, r< 3;이탈고객
# r,f,m < 3:기타

# %%
def type(x,y,z):
  if x >= 3 and y>= 3 and z >= 3:
    return "type_1"
  elif x >= 3 and y >= 3 and z < 3:
    return "type_2"
  elif x >= 3 and z >= 3 and y < 3:
    return "type_3"
  elif y >= 3 and z >= 3 and x < 3:
    return "type_4"
  else:
    return "tyep_5"

# %%
df_user['customer_type'] = df_user.apply(lambda row: type(row['recency_score'], row['frequency_score'], row['revenue_score']), axis=1)

# %%
df_user.head()
# Out:
#    customer_id  recency  frequency  revenue  recency_score  frequency_score  \
# 0     504760.0      180          1    90500              4                1
# 1     432862.0      180          1    96000              4                1
# 2      72297.0       42          9  1008120              1                4
# 3      72297.0       42          9  1008120              1                4
# 4      72297.0       42          9  1008120              1                4
#
#    revenue_score customer_type
# 0              1        tyep_5
# 1              1        tyep_5
# 2              4        type_4
# 3              4        type_4
# 4              4        type_4

# %%
df_customer = df_user[['customer_type', 'revenue']]

# %%
sns.set(palette='muted', color_codes=True, style='white')
fig, ax = plt.subplots(figsize=(12, 6))
sns.despine(left=True)
sns.histplot(data=df_customer, x='customer_type')
plt.show()

# %%
avg_revenue = df_user.groupby('customer_type').revenue.agg(['mean','min','max'])
avg_revenue
# Out:
#                        mean     min       max
# customer_type
# tyep_5         1.812629e+05       0  20000000
# type_1         6.853999e+05  278500   5580000
# type_2         1.913152e+05       0    278000
# type_3         4.734510e+05  279000  10500000
# type_4         1.095871e+06  278100   9633300
